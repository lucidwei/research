# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#一、持有A股流通市值" data-toc-modified-id="一、持有A股流通市值-1">一、持有A股流通市值</a></span></li><li><span><a href="#二、行业" data-toc-modified-id="二、行业-2">二、行业</a></span><ul class="toc-item"><li><span><a href="#1.前十大重仓股" data-toc-modified-id="1.前十大重仓股-2.1">1.前十大重仓股</a></span></li><li><span><a href="#2.行业持仓比例" data-toc-modified-id="2.行业持仓比例-2.2">2.行业持仓比例</a></span></li><li><span><a href="#3.超配比例" data-toc-modified-id="3.超配比例-2.3">3.超配比例</a></span></li></ul></li><li><span><a href="#三、风格结构" data-toc-modified-id="三、风格结构-3">三、风格结构</a></span></li></ul></div>

# %%
from it_data_tool.data_tool import *
from lowrisk_it_tools.WindPy import *
from macrotoolchain.mainAPI import *
di.display_html(getCatalogHtml(),raw=True)
from datetime import datetime,timedelta
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
di.HTML(getCatalogHtml())
h1Title('险资投资行为')
h2Title('更新时间： {}年{}月{}日'.format(Date.today().year, Date.today().month, Date.today().day))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://lf3-cdn-tos.bytecdntp.com/cdn/expire-1-M/plotly.js/2.1.0/plotly.min','https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <style>
#         @font-face {
#           font-family: 'iconfont';  /* project id 1446715 */
#           src: url('https://at.alicdn.com/t/font_1446715_7xyxjj2uxaq.eot');
#           src: url('https://at.alicdn.com/t/font_1446715_7xyxjj2uxaq.eot?#iefix') format('embedded-opentype'),
#           url('https://at.alicdn.com/t/font_1446715_7xyxjj2uxaq.woff2') format('woff2'),
#           url('https://at.alicdn.com/t/font_1446715_7xyxjj2uxaq.woff') format('woff'),
#           url('https://at.alicdn.com/t/font_1446715_7xyxjj2uxaq.ttf') format('truetype'),
#           url('https://at.alicdn.com/t/font_1446715_7xyxjj2uxaq.svg#iconfont') format('svg');
#         }
#         .iconfont{
#             font-family:"iconfont" !important;
#             font-size:16px;font-style:normal;
#             -webkit-font-smoothing: antialiased;
#             -webkit-text-stroke-width: 0.2px;
#             -moz-osx-font-smoothing: grayscale;
#         }
#         #notebook-container>.border-box-sizing:first-child{
#             position:fixed;
#             left:0px;
#             background:#fff;
#             border:0px;
#             border-right:1px solid #eee;
#             top:0px;
#             font-size:0.8em;
#             z-index:9999;
#             width:320px;
#             height:100%;
#         }
#         #notebook-container>.border-box-sizing:first-child h1{
#             margin-top:0px;
#         }
#         #notebook-container>.border-box-sizing:first-child .rendered_html{
#             overflow-y: hidden;
#             margin-right:5px;
#             height:100%;
#         }
#         #notebook-container>.border-box-sizing:first-child .toc{
#              overflow-y: auto;
#              -webkit-overflow-scrolling: touch;
#              height: calc(100% - 60px);
#              z-index: 99999;
#         }
#         #notebook-container>.border-box-sizing:first-child ul{
#             padding-left:1.2em;
#             list-style:none;
#         }
#         #notebook-container>.border-box-sizing:first-child .toc>.toc-item{
#             padding-left:0em;
#         }
#         .border-box-sizing .container{
#              width:calc(100% - 300px) !important;
#              float:right;
#         }
#         #catalogSearchInput{
#             margin:5px 0px 0px 0px;
#             width:100%;
#         }
#         .resize-bar{
#             cursor: e-resize;
#             width: 16px;
#             height: 16px;
#             top: calc(50% - 8px);
#             right: -3px;
#             position:absolute;
#         }
#         .catalog-fa{
#             float:right;
#             margin-right: 15px;
#             margin-top: 10px;
#             font-size:36px;
#             color:red;
#             cursor:pointer;
#         }
#         .catalog-icon-container{
#             position:absolute;
#             z-index: 99999;
#             width: 100%;
#             height: 30px;
#         }
#         .catalog-collapse-fa{
#             position:fixed;
#             top:5px;
#             left:5px;
#             font-size:36px;
#             color:red;
#             cursor:pointer;
#         }
#         .collapse-catalog-icon-container{
#             position:relative;
#             z-index: 99999;
#         }
#         </style>
#         <script>
#             function resizeContainer(){
#                 var leftWidth = $("#notebook-container>.border-box-sizing:first-child").width();
#                 if($("#notebook-container>.border-box-sizing:first-child").is(":hidden")) {
#                     leftWidth = 25
#                 }
#                 $("#notebook .container").css("cssText", "width:calc(100% - " + leftWidth + "px) !important");
#                 window.dispatchEvent(new Event('resize'));
#             }
#             function collapseCatalog(){
#                 $("#notebook-container>.border-box-sizing:first-child").show();
#                 $('.collapse-catalog-icon-container').remove()
#                 resizeContainer();
#                 alertMsg()
#             }
#             function shrinkCatalog(first){
#                 $("#notebook-container>.border-box-sizing:first-child").hide();
#                 $("body").append("<div class='collapse-catalog-icon-container'><i class='iconfont catalog-collapse-fa' onclick='collapseCatalog()'>&#xe6cc;</i></div>")
#                 resizeContainer();
#                 if(!first){
#                     alertMsg()
#                 }
#             }
#             <!-- 搜索框 -->
#             $("#notebook-container>.border-box-sizing:first-child h1").after("<input id='catalogSearchInput' placeholder='搜索...' />")
#             $("#catalogSearchInput").bind("input propertychange",function(event){
#                var val = $(this).val();
#                if(val == '') {
#                    $("#notebook-container>.border-box-sizing:first-child .toc li").show()
#                }else{
#                    $("#notebook-container>.border-box-sizing:first-child .toc li").each(function(){
#                        if($(this).find("a").text().indexOf(val) != -1) {
#                            $(this).show();
#                        }else{
#                            $(this).hide();
#                        }
#                    })
#                }
#             });
#             <!-- resize bar -->
#             $("#notebook-container>.border-box-sizing:first-child .toc").after("<div class='resize-bar' id='catalogResizeBtn'><i class='iconfont'>&#xe691;</i></div>");
#             $("#catalogResizeBtn").mousedown(function(beigin){
#                 var beiginX = beigin.clientX;
#                 var beiginWidth = $("#notebook-container>.border-box-sizing:first-child").width();
#                 $(document).mousemove(function(to){
#                     var toX = to.clientX;
#                     var gap = toX - beiginX;
#                     var adjustWidth = beiginWidth + gap
#                     $("#notebook-container>.border-box-sizing:first-child").width(adjustWidth);
#                     resizeContainer();
#                     return false;
#                 })
#                 $(document).mouseup(function(){
#                     $(document).unbind('mousemove');
#                     $(document).unbind('mouseup');
#                     return false;
#                 })
#                 return false;
#             })
#             if($("body.notebook_app").length == 0) {
#                 $("#notebook-container>.border-box-sizing:first-child").append("<div class='catalog-icon-container'><i class='iconfont catalog-fa' onclick='shrinkCatalog()'>&#xe6cb;</i></div>");
#             }
#             //resizeContainer();
#             //collapse();
#             if(navigator.userAgent.match(/mobile/i)) {
#                 //手机端默认隐藏显示滑块
#                 shrinkCatalog(true);
#                 $("#notebook-container>.border-box-sizing:first-child").css('width','220px');
#                 $("#notebook-container>.border-box-sizing:first-child .rendered_html").css({'margin-right':'0'});
#                 $("#catalogResizeBtn").hide();
#             }
#         </script>
# <h1 class="title">险资投资行为</h1>

# %% [markdown]
# # 一、持有A股流通市值

# %% [markdown]
# 计算方法：保险与社保投资金额之和
# + 保险：采用保险资金运用余额中分项计算，2013-06-30之前的股票和证券投资部分，采用2013-06-30的股票和证券投资与投资之比\*对应时间投资部分；2013-06-30及之后采用股票和证券投资部分；因为其中不仅含有股票，股票和证券投资部分\*0.575为投资向股票的市值
# + 社保：中国A股前十大流通股东中股东名称为3种社保基金投资渠道，持有数量\*当日收盘价，整体求和后/0.4

# %%
# 所用日期序列
start_date = '20051231'
end_date = datetime.today().strftime('%Y%m%d')
date_list_base = pd.date_range(start_date,end_date,freq='Q')
date_list = [d.strftime('%Y%m%d') for d in date_list_base]

# %%
# A股流通市值
def cal_a_flow_nav():
    sql = '''
        select S_INFO_WINDCODE as scode, TRADE_DT, S_DQ_MV/1e4 as flow_market_value
        from ads_wind_AShareEODDerivativeIndicator_a
        where TRADE_DT in {}
        order by TRADE_DT, S_INFO_WINDCODE
        '''.format(tuple(date_list))
    df = get_quant_db_hz(sql).groupby(['trade_dt'])['flow_market_value'].sum()
    df.index = pd.to_datetime(df.index)
    return df

a_flow_nav = cal_a_flow_nav()

# %%
# 前10大流通股东，亿股
sql = '''
    select s_info_windcode as scode, s_holder_enddate as trade_dt, s_holder_holdercategory as type, s_holder_name as holder, s_holder_quantity/1e8 as shares
    from ads_wind_asharefloatholder_a
    where s_holder_enddate in {}
    order by s_holder_enddate,s_info_windcode
    '''.format(tuple(date_list))
float_holders = get_quant_db_hz(sql)

# A股收盘价
trade_date_list = w.tdays("2005-10-31", datetime.today().strftime('%Y%m%d'), "Period=Q",usedf=True)[1].index.tolist()
trade_date_list = [x.strftime('%Y%m%d') for x in trade_date_list]
sql = '''
    select S_INFO_WINDCODE as scode, TRADE_DT as old_dt, S_DQ_CLOSE as price
    from ads_wind_ashareeodprices_a
    where TRADE_DT in {}
    order by TRADE_DT, S_INFO_WINDCODE
    '''.format(tuple(trade_date_list))
astock_price = get_quant_db_hz(sql)
# 处理日期
date_df = pd.DataFrame(columns=['old_dt','trade_dt'])
if len(trade_date_list)!=len(date_list):
    trade_date_list = trade_date_list[:-1]
date_df['old_dt'] = trade_date_list
date_df['trade_dt'] = date_list
astock_price = pd.merge(astock_price,date_df,on=['old_dt']).drop(['old_dt'],axis=1)

# %%
# 社保
shebao_list = ['全国社会保障基金理事会','全国社保基金','基本养老保险基金']

def cal_shebao_nav():
    # 取出社保
    rest_holders = float_holders[float_holders.type=='2']
    df = pd.DataFrame()
    for sb in shebao_list:
        tmp = rest_holders[rest_holders.holder.str.contains(sb)]
        df = pd.concat([df,tmp],axis=0)
    df = df.sort_values(['trade_dt','scode']).drop_duplicates()
    # 计算市值
    df = pd.merge(df,astock_price,on=['scode','trade_dt'])
    df['shebao_market_value'] = df['shares']*df['price']
    df = df.groupby(['trade_dt'])['shebao_market_value'].sum()
    df.index = pd.to_datetime(df.index)
    df /= 0.4
    return df

shebao_nav = cal_shebao_nav()

# %%
# 保险
def cal_baoxian_nav():
    # 保险数据：保险资金运用余额
    df = w.edb("M0012274,M5876382", start_date, end_date,"Fill=Previous",usedf=True)[1]
    df = df.loc[date_list_base,:]
    df.columns = ['投资总额','baoxian_market_value']
    df['投资总额'] /= 1e4
    df1 = df.dropna()
    bili = df1.iloc[0,1]/df1.iloc[0,0]
    df['股票证券投资2'] = df['投资总额']*bili
    df['baoxian_market_value'] = df['baoxian_market_value'].fillna(df['股票证券投资2'])
    # 股票占股票证券投资比例自定的，观察中信数据得知
    df['baoxian_market_value'] *= 0.575
    df = df['baoxian_market_value']
    return df

baoxian_nav = cal_baoxian_nav()

# %%
nav = pd.concat([shebao_nav,baoxian_nav,a_flow_nav],axis=1).dropna()
nav['xianzi'] = nav['shebao_market_value']+nav['baoxian_market_value']
nav['bili'] = nav['xianzi']/nav['flow_market_value']*100

# %%
from lowrisk.CustomECharts import *

s = Data(timeList=nav.index,dataList=nav['xianzi'],title='险资持有A股流通市值（亿元）')
bar_gra = barGraph(s,color='palevioletred',stack='1')
s = Data(timeList=nav.dropna().index,dataList=nav.dropna()['bili'],title='占A股总流通市值之比（%）')
line_gra = lineGraph(s,color='midnightblue',yAxisIndex=1)
plot_arr = [bar_gra,line_gra]

goechart(plot_arr,setLayout(xAxis = setAxis(type="time"),
                            yAxis = [setAxis(),setAxis()],
                            title=setTitle("险资持有A股流通市值"),
                            legend=dict(
                                        x="center",
                                        y="bottom",
                                        orient='horizontal',
                                        padding=[0,50,0,0]
                                        ),
                            grid=[{
                                    "left":"5%",
                                    "right":"10%",
                                    "height":"70%"
                                }],
                            dataZoom=[
                                        {
                                            "type":"slider",
                                            "xAxisIndex":0,
                                            "f'selector':TrueilterMode":'empty',
                                            "bottom":"8%"
                                        },
                                        {
                                            "type":"slider",
                                            "yAxisIndex":0,
                                            "filterMode":'empty'
                                        },
                                    ]
                           )
        )
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="c94a20d97de2421a9c44ed61b31e3c58" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c94a20d97de2421a9c44ed61b31e3c58 = echarts.init(
#                     document.getElementById('c94a20d97de2421a9c44ed61b31e3c58'), 'white', {renderer: 'canvas'});
#                 var option_c94a20d97de2421a9c44ed61b31e3c58 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": 80,
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": [
#         {
#             "type": "value",
#             "name": null,
#             "gridIndex": 0,
#             "position": "right",
#             "axisLine": {
#                 "onZero": false,
#                 "lineStyle": {
#                     "color": "black",
#                     "width": 1
#                 }
#             },
#             "nameGap": 5,
#             "axisLabel": {
#                 "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 &&

# %% [markdown]
# # 二、行业

# %% [markdown]
# ## 1.前十大重仓股

# %% [markdown]
# 计算方法：对于前十大流通股东中险资持有的个股，找合计持股市值最大的前10只股票，作为持股金额

# %%
def cal_xianzi_specific():
    # 取出社保
    rest_holders = float_holders[float_holders.type=='2']
    df = pd.DataFrame()
    for sb in shebao_list:
        tmp = rest_holders[rest_holders.holder.str.contains(sb)]
        df = pd.concat([df,tmp],axis=0)
    rest_holders = pd.concat([rest_holders,df],axis=0).drop_duplicates(keep=False)
    df = pd.merge(df,astock_price,on=['scode','trade_dt'])
    df['guimo'] = df['shares']*df['price']
    df['guimo'] /= 0.4
    # 取出保险
    df1 = rest_holders[rest_holders.holder.str.contains('保险')]
    df1 = pd.merge(df1,astock_price,on=['scode','trade_dt'])
    df1['guimo'] = df1['shares']*df1['price']
    df = pd.concat([df,df1],axis=0)
    df.trade_dt = pd.to_datetime(df.trade_dt)
    df = df.groupby(['trade_dt','scode'])['guimo'].sum().reset_index()
    return df

xianzi_specific = cal_xianzi_specific()

# %%
def cal_xianzi_top10(df):
    df = df.copy()
    df = df.assign(rank = lambda x:x.groupby(['trade_dt'])['guimo'].rank(ascending=False,method='first'))
    df = df[df['rank']<=10]
    # 股票名称
    name_list = df.scode.drop_duplicates().tolist()
    sql = '''
        select s_info_windcode as scode, s_info_name as sname
        from ads_wind_asharedescription_a
        where s_info_windcode in {}
        '''.format(tuple(name_list))
    names = get_quant_db_hz(sql)
    # 已经是亿元单位了
    df = pd.merge(df,names,on=['scode']).sort_values(['trade_dt','rank'])
    return df

xianzi_top10 = cal_xianzi_top10(xianzi_specific)

# %%
from lowrisk.CustomECharts import *
date_range = sorted(list(set(xianzi_top10['trade_dt'].tolist())))
rank_range = sorted(list(set(xianzi_top10['rank'].tolist())))
colors = ['crimson','darkorange','gold','mediumaquamarine','lightskyblue','dodgerblue','slateblue','violet','hotpink','mediumvioletred']
plot_arr = []
for i in range(len(rank_range)):
    r = rank_range[i]
    df = xianzi_top10[xianzi_top10['rank']==r].sort_values(['trade_dt'])
    s = Data(timeList=df.trade_dt.tolist(),dataList=df.guimo.tolist(),title='top{}'.format(i+1))
    bar_gra = barGraph(s,color=colors[i],label={'position':'insideTop',
                                                'show': True,
                                                'rotate':60,
                                                'formatter':'{@[2]}',
                                                'align':'left',
                                                'verticalAlign':'middle'
                                               })
    for i in range(len(bar_gra['data'])):
        bar_gra['data'][i].append(df.sname.tolist()[i])
    plot_arr.append(bar_gra)

goechart(plot_arr,setLayout(xAxis = setAxis(type="time"),
                            yAxis = setAxis(),
                            title=setTitle("险资季度前十大重仓股持有总市值（亿元）"),
                            legend=dict(
                                        x="center",
                                        y="bottom",
                                        orient='horizontal',
                                        padding=[0,50,0,0]
                                        ),
                            grid=[{
                                    "left":"5%",
                                    "right":"10%",
                                    "height":"70%"
                                }],
                            dataZoom=[
                                        {
                                            "type":"slider",
                                            "xAxisIndex":0,
                                            "f'selector':TrueilterMode":'empty',
                                            "bottom":"8%"
                                        },
                                        {
                                            "type":"slider",
                                            "yAxisIndex":0,
                                            "filterMode":'empty'
                                        },
                                    ]
                           )
        )
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="6ed6460ca5ad4961abaeaf77f24aa361" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6ed6460ca5ad4961abaeaf77f24aa361 = echarts.init(
#                     document.getElementById('6ed6460ca5ad4961abaeaf77f24aa361'), 'white', {renderer: 'canvas'});
#                 var option_6ed6460ca5ad4961abaeaf77f24aa361 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %% [markdown]
# ## 2.行业持仓比例

# %% [markdown]
# 计算方法：根据每季度持股市值，加总求得每个行业的季度市值，计算整体占比

# %%
sql = '''
    select wind_code as scode, citic_industry as industry
    from ads_wind_ahshareciticsindustries_style_a
    '''
ind = get_quant_db_hz(sql)
xianzi_specific = pd.merge(xianzi_specific,ind,on=['scode'],how='left')
xianzi_specific['industry'] = xianzi_specific['industry'].fillna('综合')
xianzi_specific.trade_dt = pd.to_datetime(xianzi_specific.trade_dt)
# 行业和中信一级行业对齐
xianzi_specific.loc[xianzi_specific.industry=='保险Ⅱ','industry'] = '非银行金融'
xianzi_specific.loc[xianzi_specific.industry=='证券Ⅱ','industry'] = '非银行金融'
xianzi_specific.loc[xianzi_specific.industry=='多元金融','industry'] = '非银行金融'
xianzi_specific.loc[xianzi_specific.industry=='酒类','industry'] = '食品饮料'
xianzi_specific.loc[xianzi_specific.industry=='食品','industry'] = '食品饮料'
xianzi_specific.loc[xianzi_specific.industry=='饮料','industry'] = '食品饮料'

# %%
def cal_xianzi_indratio(df):
    df = df.copy()
    df = df.groupby(['trade_dt','industry'])['guimo'].sum().reset_index()
    df = df.assign(tot_guimo = lambda x:x.groupby(['trade_dt'])['guimo'].transform('sum'),
                  w = lambda x:x['guimo']/x['tot_guimo'])
    df = df[['trade_dt','industry','w']].pivot_table(index=['trade_dt'],columns=['industry'],values=['w'])['w']
    df = df*100
    return df

xianzi_indratio = cal_xianzi_indratio(xianzi_specific)

# %%
bankuai = {'上游周期':['石油石化','基础化工','煤炭','钢铁','有色金属','建筑','建材','农林牧渔'],
           '中游制造':['电力及公用事业','电力设备及新能源','汽车','机械','交通运输','轻工制造','国防军工'],
           '大消费':['商贸零售','食品饮料','纺织服装','家电','消费者服务','医药'],
           'TMT':['电子','计算机','通信','传媒'],
           '金融地产':['银行','非银行金融','房地产','综合金融'],
           '其他':['综合']}
dabankuai = ['上游周期','中游制造','大消费','TMT','金融地产','其他']

# %%
def draw(name):
    df = xianzi_indratio[bankuai[name]].copy()
    plot_arr = []
    for i in range(len(df.columns)):
        column = df.columns[i]
        color = colors[i]
        s = Data(timeList=df.index,dataList=df[column].tolist(),title=column)
        line_gra = lineGraph(s,color=color)
        plot_arr.append(line_gra)
    g = goechart(plot_arr,setLayout(xAxis = setAxis(type="time"),
                                    yAxis = setAxis(),
                                    title=setTitle("险资{}板块季度持仓比例（%）".format(name)),
                                    legend=dict(
                                                x="center",
                                                y="bottom",
                                                orient='horizontal',
                                                padding=[0,50,0,0]
                                                ),
                                    grid=[{
                                            "left":"5%",
                                            "right":"10%",
                                            "height":"70%"
                                        }],
                                    dataZoom=[
                                                {
                                                    "type":"slider",
                                                    "xAxisIndex":0,
                                                    "f'selector':TrueilterMode":'empty',
                                                    "bottom":"8%"
                                                },
                                                {
                                                    "type":"slider",
                                                    "yAxisIndex":0,
                                                    "filterMode":'empty'
                                                },
                                            ]
                                   )
                )
    return g

graphs = []
for name in dabankuai:
    graphs.append(draw(name))

# %%
graphs[0]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="de39036e54a148a3983fafb74db0f42f" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_de39036e54a148a3983fafb74db0f42f = echarts.init(
#                     document.getElementById('de39036e54a148a3983fafb74db0f42f'), 'white', {renderer: 'canvas'});
#                 var option_de39036e54a148a3983fafb74db0f42f = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %%
graphs[1]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="37fb3db9ce56418c9d3a673cc50615ca" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_37fb3db9ce56418c9d3a673cc50615ca = echarts.init(
#                     document.getElementById('37fb3db9ce56418c9d3a673cc50615ca'), 'white', {renderer: 'canvas'});
#                 var option_37fb3db9ce56418c9d3a673cc50615ca = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %%
graphs[2]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="9e37f8428d3f43038f64acc6ed4f8c53" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9e37f8428d3f43038f64acc6ed4f8c53 = echarts.init(
#                     document.getElementById('9e37f8428d3f43038f64acc6ed4f8c53'), 'white', {renderer: 'canvas'});
#                 var option_9e37f8428d3f43038f64acc6ed4f8c53 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %%
graphs[3]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="b9a3c230b90c4f9dae702e1d273115d0" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b9a3c230b90c4f9dae702e1d273115d0 = echarts.init(
#                     document.getElementById('b9a3c230b90c4f9dae702e1d273115d0'), 'white', {renderer: 'canvas'});
#                 var option_b9a3c230b90c4f9dae702e1d273115d0 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %%
graphs[4]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="88b6f30999da4aeea47c14c0e224f2bd" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_88b6f30999da4aeea47c14c0e224f2bd = echarts.init(
#                     document.getElementById('88b6f30999da4aeea47c14c0e224f2bd'), 'white', {renderer: 'canvas'});
#                 var option_88b6f30999da4aeea47c14c0e224f2bd = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %%
graphs[5]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="698923df5c0448c2b1ce6095a056d870" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_698923df5c0448c2b1ce6095a056d870 = echarts.init(
#                     document.getElementById('698923df5c0448c2b1ce6095a056d870'), 'white', {renderer: 'canvas'});
#                 var option_698923df5c0448c2b1ce6095a056d870 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %% [markdown]
# ## 3.超配比例

# %% [markdown]
# 计算方法：计算各个行业在A股自由流通市值中的比例，再计算各个行业在险资持仓中的比例，计算两者之差

# %%
def get_ashares_nav(sd,ed):
    date_list = pd.date_range(sd,ed,freq='Q')
    date_list = [x.strftime('%Y%m%d') for x in date_list]
    sql = '''
        select s_info_windcode as scode, trade_dt as ann_date, s_dq_mv as nav
        from ads_wind_ashareeodderivativeindicator_a
        where trade_dt in {}
        '''.format(tuple(date_list))
    df = get_quant_db_hz(sql)
    sql = '''
        select wind_code as scode, citic_industry as industry
        from ads_wind_ahshareciticsindustries_style_a
        '''
    ind = get_quant_db_hz(sql)
    df = pd.merge(df,ind,on=['scode'],how='left')
    df['industry'] = df['industry'].fillna('综合')
    df.ann_date = pd.to_datetime(df.ann_date)
    df = df.dropna()
    # 行业和中信一级行业对齐
    df.loc[df.industry=='保险Ⅱ','industry'] = '非银行金融'
    df.loc[df.industry=='证券Ⅱ','industry'] = '非银行金融'
    df.loc[df.industry=='多元金融','industry'] = '非银行金融'
    df.loc[df.industry=='酒类','industry'] = '食品饮料'
    df.loc[df.industry=='食品','industry'] = '食品饮料'
    df.loc[df.industry=='饮料','industry'] = '食品饮料'
    return df
ashares_nav = get_ashares_nav(start_date,end_date)

# %%
def cal_xianzi_excess(df1,df2):
    ashares_nav_tot = df1.groupby(['ann_date','industry'])['nav'].sum().reset_index().sort_values(['ann_date'])
    ashares_nav_tot['nav'] /= 1e8
    ashares_nav_tot = ashares_nav_tot.assign(tot = lambda x:x.groupby(['ann_date'])['nav'].transform('sum'),
                                             nav = lambda x:x['nav']/x['tot']*100)
    df2 = df2.stack().reset_index().rename(columns={0:'w','trade_dt':'ann_date'})
    # Ashares多的是周末
    df = pd.merge(ashares_nav_tot,df2,on=['ann_date','industry'])
    df['excess'] = df['w'] - df['nav']
    df = df[['ann_date','industry','excess']].pivot_table(index=['ann_date'],columns=['industry'],values=['excess'])['excess']
    return df

xianzi_excess = cal_xianzi_excess(ashares_nav,xianzi_indratio)

# %%
def draw(name):
    df = xianzi_excess[bankuai[name]].copy()
    plot_arr = []
    for i in range(len(df.columns)):
        column = df.columns[i]
        color = colors[i]
        s = Data(timeList=df.index,dataList=df[column].tolist(),title=column)
        line_gra = lineGraph(s,color=color)
        plot_arr.append(line_gra)
    g = goechart(plot_arr,setLayout(xAxis = setAxis(type="time"),
                                    yAxis = setAxis(),
                                    title=setTitle("险资{}板块日度超配比例（%）".format(name)),
                                    legend=dict(
                                                x="center",
                                                y="bottom",
                                                orient='horizontal',
                                                padding=[0,50,0,0]
                                                ),
                                    grid=[{
                                            "left":"5%",
                                            "right":"10%",
                                            "height":"70%"
                                        }],
                                    dataZoom=[
                                                {
                                                    "type":"slider",
                                                    "xAxisIndex":0,
                                                    "f'selector':TrueilterMode":'empty',
                                                    "bottom":"8%"
                                                },
                                                {
                                                    "type":"slider",
                                                    "yAxisIndex":0,
                                                    "filterMode":'empty'
                                                },
                                            ]
                                   )
                )
    return g

graphs = []
for name in dabankuai:
    graphs.append(draw(name))

# %%
graphs[0]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="92e17bf20d934b6589469a3870705758" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_92e17bf20d934b6589469a3870705758 = echarts.init(
#                     document.getElementById('92e17bf20d934b6589469a3870705758'), 'white', {renderer: 'canvas'});
#                 var option_92e17bf20d934b6589469a3870705758 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %%
graphs[1]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="07987530ed764f5593d7e1d41c74a82d" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_07987530ed764f5593d7e1d41c74a82d = echarts.init(
#                     document.getElementById('07987530ed764f5593d7e1d41c74a82d'), 'white', {renderer: 'canvas'});
#                 var option_07987530ed764f5593d7e1d41c74a82d = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %%
graphs[2]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="9446324100274e41a4761c31351b2779" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9446324100274e41a4761c31351b2779 = echarts.init(
#                     document.getElementById('9446324100274e41a4761c31351b2779'), 'white', {renderer: 'canvas'});
#                 var option_9446324100274e41a4761c31351b2779 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %%
graphs[3]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="958190e010b94902b154715af1d652e4" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_958190e010b94902b154715af1d652e4 = echarts.init(
#                     document.getElementById('958190e010b94902b154715af1d652e4'), 'white', {renderer: 'canvas'});
#                 var option_958190e010b94902b154715af1d652e4 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %%
graphs[4]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="a33a9f71c47d4d1699439b54055ec537" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a33a9f71c47d4d1699439b54055ec537 = echarts.init(
#                     document.getElementById('a33a9f71c47d4d1699439b54055ec537'), 'white', {renderer: 'canvas'});
#                 var option_a33a9f71c47d4d1699439b54055ec537 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %%
graphs[5]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="2aec7d4a5a4d407aa23b7dc5dd1f41b9" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2aec7d4a5a4d407aa23b7dc5dd1f41b9 = echarts.init(
#                     document.getElementById('2aec7d4a5a4d407aa23b7dc5dd1f41b9'), 'white', {renderer: 'canvas'});
#                 var option_2aec7d4a5a4d407aa23b7dc5dd1f41b9 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": "5%",
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "nameGap": 5,
#         "position": "right",
#         "type": "value",
#         "name": null,
#         "gridIndex": 0,
#         "axisLabel": {
#             "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }        if (r === undefined)

# %% [markdown]
# # 三、风格结构

# %% [markdown]
# 计算方法：计算险资所有股票按照市值加权的PE、PB

# %%
def get_pepb(df,sd,ed):
    stock_list = list(set(df.scode.tolist()))
    date_list = pd.date_range(sd,ed,freq='Q')
    date_list = [x.strftime('%Y%m%d') for x in date_list]
    sql = '''
        select s_info_windcode as scode,trade_dt as trade_dt,s_val_pe_ttm as pe,s_val_pb_new as pb
        from ads_wind_ashareeodderivativeindicator_a
        where s_info_windcode in {} and trade_dt in {}
        '''.format(tuple(stock_list),tuple(date_list))
    df1 = get_quant_db_hz(sql)
    sql = '''
        select s_info_windcode as scode,financial_trade_dt as trade_dt,s_val_pe_ttm as pe,s_val_pb_new as pb
        from ads_wind_hkshareeodderivativeindex_a
        where s_info_windcode in {} and financial_trade_dt in {}
        '''.format(tuple(stock_list),tuple(date_list))
    df2 = get_quant_db_hz(sql)
    df = pd.concat([df1,df2],axis=0)
    df.trade_dt = pd.to_datetime(df.trade_dt)
    return df

pepb = get_pepb(xianzi_specific,start_date,end_date)

# %%
def cal_xianzi_pepb(df,tmp):
    df = df.copy()
    df = df.groupby(['trade_dt','scode'])['guimo'].sum().reset_index()
    df = df.assign(tot_nav = lambda x:x.groupby(['trade_dt'])['guimo'].transform('sum'),
                  guimo = lambda x:x['guimo']/x['tot_nav'])
    df = df.drop(['tot_nav'],axis=1)
    df = pd.merge(df,tmp,on=['scode','trade_dt'])
    df['pe'] *= df['guimo']
    df['pb'] *= df['guimo']
    df = df.groupby(['trade_dt'])[['pe','pb']].sum().reset_index()
    return df

xianzi_pepb = cal_xianzi_pepb(xianzi_specific,pepb)

# %%
from lowrisk.CustomECharts import *
s = Data(timeList=xianzi_pepb.trade_dt.tolist(),dataList=xianzi_pepb['pe'].tolist(),title='PE')
line_gra1 = lineGraph(s,color='midnightblue')
s = Data(timeList=xianzi_pepb.trade_dt.tolist(),dataList=xianzi_pepb['pb'].tolist(),title='PB')
line_gra2 = lineGraph(s,color='palevioletred',yAxisIndex=1)
plot_arr = [line_gra1,line_gra2]

goechart(plot_arr,
         setLayout(xAxis = setAxis(type="time"),
                   yAxis=[
                            setAxis(title='PE'),
                            setAxis(title='PB',range=[0,20])
                         ],
                   title=setTitle("险资持仓市值加权估值"),
                   legend=dict(
                                x="center",
                                y="bottom",
                                orient='horizontal',
                                padding=[0,50,0,0]
                                ),
                            grid=[{
                                    "left":"5%",
                                    "right":"10%",
                                    "height":"70%"
                                }],
                            dataZoom=[
                                        {
                                            "type":"slider",
                                            "xAxisIndex":0,
                                            "f'selector':TrueilterMode":'empty',
                                            "bottom":"8%"
                                        },
                                        {
                                            "type":"slider",
                                            "yAxisIndex":0,
                                            "filterMode":'empty'
                                        },
                                    ]
                           )
        )
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://lowrisk-appdata.oss-cn-hangzhou.aliyuncs.com/js/echarts/echarts.min'
#         }
#     });
#     require(['echarts'],function(echarts){
# 		window.echarts = echarts
# 	})
# </script>
#
#         <div id="9df0e8ae76ff4298ac13b8a88fee5439" style="width:100%; height:530px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9df0e8ae76ff4298ac13b8a88fee5439 = echarts.init(
#                     document.getElementById('9df0e8ae76ff4298ac13b8a88fee5439'), 'white', {renderer: 'canvas'});
#                 var option_9df0e8ae76ff4298ac13b8a88fee5439 = {
#     "legend": {
#         "bottom": 0,
#         "x": "center",
#         "y": "bottom",
#         "orient": "horizontal",
#         "padding": [
#             0,
#             50,
#             0,
#             0
#         ]
#     },
#     "grid": [
#         {
#             "left": 80,
#             "right": "10%",
#             "height": "70%"
#         }
#     ],
#     "tooltip": {
#         "trigger": "axis",
#         "confine": true,
#         "formatter": function(params) {    function formatValue(value, type = 'thousand', decimals = 2) {        let num = Number(value);        if (type == 'thousand') {            return formatMoney(num, decimals);        } else if (type == 'hundred') {            return (num * 100).toFixed(decimals) + '%';        } else {            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {            n = n > 0 && n <= 20 ? n : 0;            s = parseFloat(s).toFixed(n) + '';            var l = s.split('.')[0].split('').reverse(),                r = s.split('.')[1];            var t = '';            for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 && (i + 1) != l.length ? ',' : ''); }            if (r === undefined) {                return t.split('').reverse().join('');            } else {                return t.split('').reverse().join('') + '.' + r;            }        }    }    function dateFormatFunction(value,tf){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf;    }    let chartObj = echarts.getInstanceByDom(event.target.parentNode.parentNode);    let option = chartObj.getOption();    let series = option.series;    let p = '';    let head = '';    if(Array.isArray(params)){        head = params[0].axisValueLabel;    }else{        params = [params];    }    let date = new Date(params[0].data[0]);    /* 获取head */    if (date.toString() != 'Invalid Date') {        let year = date.getFullYear();        let month = (date.getMonth() + 1 < 10) ? '0' + (date.getMonth() + 1) : (date.getMonth() + 1);        let day = date.getDate() < 10 ? '0' + date.getDate() : date.getDate();        if(year == '1904' || year == '1905'){            /*季节图不展示年份*/            head = month + '-' + day + '</br>';        }else{            head = year + '-' + month + '-' + day + '</br>';        }    }    p += head;    params.forEach(i => {        let seriesIndex = i.seriesIndex;        let yAxisIndex = series[seriesIndex].yAxisIndex ? series[seriesIndex].yAxisIndex : 0;        if (!Array.isArray(option.yAxis)) {            option.yAxis = [option.yAxis];        }        let customFormatter = option.yAxis[yAxisIndex].customFormatter;        let name = i.seriesName;        let value = i.value;        if (Array.isArray(value)) {            value = value[1];        }        if (customFormatter === undefined) {            value = isNaN(value) ? value : Number(value).toFixed(2);            p += i.marker + name + ':' + value + '</br>';        } else {            if (isNaN(value)) {                p += i.marker + name + ':' + value + '</br>';            } else {                let params = customFormatter.substring(customFormatter.indexOf('(') + 1, customFormatter.lastIndexOf(')')).replace(/'/g, '').replace(/\"/g, '').split(',');                let decimals = params[0];                let type = params[1];                let vStr = formatValue(value, type, decimals);                p += i.marker +  ...
#     },
#     "visualMap": [],
#     "toolbox": {
#         "feature": {
#             "dataZoom": {
#                 "yAxisIndex": "none"
#             },
#             "restore": {}
#         },
#         "top": 0,
#         "right": 0
#     },
#     "xAxis": {
#         "axisLine": {
#             "onZero": false,
#             "lineStyle": {
#                 "color": "black",
#                 "width": 1
#             }
#         },
#         "splitLine": {
#             "show": false
#         },
#         "type": "time",
#         "name": null,
#         "gridIndex": 0,
#         "position": "right",
#         "nameGap": 5,
#         "axisLabel": {
#             "formatter":     function(value,index){        let date = new Date(value);        let month = date.getMonth()+1;        let timeMap = {            '%y': date.getFullYear().toString().substring(2),            '%Y': date.getFullYear(),            '%m': (date.getMonth() + 1 < 10)?'0' + (date.getMonth() + 1):(date.getMonth() + 1),            '%d': date.getDate() < 10 ?'0'+date.getDate():date.getDate(),            '%H': date.getHours() < 10 ?'0'+date.getHours():date.getHours(),            '%I': date.getHours()>12?date.getHours()-12:date.getHours(),            '%M': date.getMinutes() < 10 ?'0'+date.getMinutes():date.getMinutes(),            '%S': date.getSeconds() < 10 ?'0'+date.getSeconds():date.getSeconds(),            '%b': date.toString().split(' ')[1],            '%B': date.toString().split(' ')[1],            '%c': date.toLocaleString(),            '%Q': 'Q' + Math.floor((month % 3 == 0 ? (month / 3) : (month / 3 + 1))),            '%%': '%',        };        let tf = '%Y-%m-%d';        for (let key of Object.keys(timeMap)){            let value = timeMap[key];            tf = tf.replace(new RegExp(key,'g'),value);        }        return tf    }
#         }
#     },
#     "yAxis": [
#         {
#             "type": "value",
#             "name": "PE",
#             "gridIndex": 0,
#             "position": "right",
#             "axisLine": {
#                 "onZero": false,
#                 "lineStyle": {
#                     "color": "black",
#                     "width": 1
#                 }
#             },
#             "nameGap": 5,
#             "axisLabel": {
#                 "formatter":     function(value,index){        let num = Number(value);        let decimals = 2;        let type = 'thousand';        if (type == 'thousand') {            return formatMoney(num,decimals);        }else if(type == 'hundred'){            return (num * 100) .toFixed(decimals) + '%';        }else{            return '' + num.toFixed(decimals);        }        function formatMoney(s, n) {        n = n > 0 && n <= 20 ? n : 0;        s = parseFloat(s).toFixed(n) + '';        var l = s.split('.')[0].split('').reverse(),            r = s.split('.')[1];        var t = '';        for (var i = 0; i < l.length; i++) { t += l[i] + ((i + 1) % 3 == 0 &&
